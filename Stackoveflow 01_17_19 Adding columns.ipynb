# %% [markdown]
# https://stackoverflow.com/questions/54234223/adding-new-columns-to-a-dataframe-based-on-value-from-other-column

# %%
d = {'switchopen': [True, True, False, False, False, False, False, False, False, False, False, False, False, True, True, False, False, True ],
     'switchclose': [ False, False, False, False, False, True, True, True, True, True, False, False, False, False, False, False, False, False]}

df = pd.DataFrame(data=d)

# %%
df.loc[(df['switchopen'] == True) & (df['switchclose'] == False), 'Position'] = 'open'
df.loc[(df['switchopen'] == False) & (df['switchclose'] == True), 'Position'] = 'closed'
df.loc[(df['switchopen'] == False) & (df['switchclose'] == False), 'Position'] = 'moving'

# %%
df
# Out:
#     switchopen  switchclose Position
# 0         True        False     open
# 1         True        False     open
# 2        False        False   moving
# 3        False        False   moving
# 4        False        False   moving
# 5        False         True   closed
# 6        False         True   closed
# 7        False         True   closed
# 8        False         True   closed
# 9        False         True   closed
# 10       False        False   moving
# 11       False        False   moving
# 12       False        False   moving
# 13        True        False     open
# 14        True        False     open
# 15       False        False   moving
# 16       False        False   moving
# 17        True        False     open

# %%
import numpy as np
df.loc[:,'position1'] = np.where((df['switchopen'] == True) & (df['switchclose'] == False), 'open',
                        np.where((df['switchopen'] == False) & (df['switchclose'] == True), 'closed',
                        np.where((df['switchopen'] == False) & (df['switchclose'] == False), 'moving',
                                np.nan)))

# %%
df
# Out:
#     switchopen  switchclose Position position1
# 0         True        False     open      open
# 1         True        False     open      open
# 2        False        False   moving    moving
# 3        False        False   moving    moving
# 4        False        False   moving    moving
# 5        False         True   closed    closed
# 6        False         True   closed    closed
# 7        False         True   closed    closed
# 8        False         True   closed    closed
# 9        False         True   closed    closed
# 10       False        False   moving    moving
# 11       False        False   moving    moving
# 12       False        False   moving    moving
# 13        True        False     open      open
# 14        True        False     open      open
# 15       False        False   moving    moving
# 16       False        False   moving    moving
# 17        True        False     open      open
