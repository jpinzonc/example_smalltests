# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame({'Station':np.random.randint(100, size=1000)}).astype(str).radd('station')
print (df.head())
# Out:
#      Station
# 0  station65
# 1  station44
# 2  station24
# 3  station78
# 4  station70

# %%
df_counts = df['Station'].value_counts().to_frame().reset_index(drop =  False)
df_counts.columns = ['Station', 'Counts']

# %%
sns.countplot(x='Station', 
              data=df, 
              palette="bright",
              order=df['Station'].value_counts().index[:5])

# %%
sns.countplot(x="Station", data=df)

# %%
df2 = pd.read_clipboard()
#df2 = df2.reset_index()
#df2.columns = ['Genre', 'count']
df2
# Out:
#                 Genre
# Strategy       174.50
# Adventure      237.69
# Puzzle         243.02
# Simulation     390.42
# Fighting       447.48
# Racing         728.90
# Misc           803.18
# Platform       828.08
# Role-Playing   934.40
# Shooter       1052.94
# Sports        1249.47
# Action        1745.27

# %%
df2.T.plot( kind='bar', sort_columns=True, cmap='tab20')

# %%
df2.plot()

# %%
dd = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)
dd
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.968120  1.527695  0.649819  0.493713  0.323924  1.972554  1.072415
# 1  1.726515  0.633569  0.022455  0.212486  1.458299  1.477838  0.234056
# 2  2.174746  0.861902  1.245932  0.651683  0.036235  0.023488  0.418329
# 3  0.596224  1.566239  0.078763  0.807660  0.211300  0.448453  0.838596
# 4  1.819277  0.954153  1.407378  0.738992  0.444139  0.776873  0.020001
# 5  0.430658  1.678853  0.473061  0.971024  1.407674  0.943146  1.329302
# 6  2.065399  1.159527  1.217953  0.108076  1.308853  0.320371  0.480043
# 7  0.598529  0.212366  0.240294  0.559745  0.351669  0.636633  0.330584
# 8  1.508778  0.649824  0.485291  0.836610  0.945633  0.792851  0.363656
# 9  1.790361  0.644049  0.476450  1.100993  0.914291  0.118887  0.014367
#
#           7         8         9
# 0  0.632262  1.530670  1.288064
# 1  0.277397  1.432177  1.272579
# 2  0.774787  1.640247  0.962281
# 3  0.031793  1.144685  0.084709
# 4  1.216922  0.351567  0.638837
# 5  1.317284  0.824079  1.187626
# 6  2.524360  0.568513  0.081167
# 7  1.601341  1.802254  0.900290
# 8  0.238090  0.831207  0.427429
# 9  0.559709  0.944626  0.024326

# %%
dd.plot()

# %%
df2.T.plot.bar(cmap='tab20_r')
