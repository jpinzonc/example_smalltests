# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

date_1 = datetime(2017,3,4).date()
days = pd.date_range(date_1, date_1 + timedelta(days = 200), freq='D')
np.random.seed(seed=1111)
data = np.random.randint(1, high=100, size=len(days))
df = pd.DataFrame({'date': days, 'number': data})
df = df.set_index('date')
display(df)
# Out:
#             number
# date
# 2017-03-04      29
# 2017-03-05      56
# 2017-03-06      82
# 2017-03-07      13
# 2017-03-08      35
# 2017-03-09      53
# 2017-03-10      25
# 2017-03-11      23
# 2017-03-12      21
# 2017-03-13      12
# 2017-03-14      15
# 2017-03-15       9
# 2017-03-16      13
# 2017-03-17      87
# 2017-03-18       9
# 2017-03-19      63
# 2017-03-20      62
# 2017-03-21      52
# 2017-03-22      43
# 2017-03-23      77
# 2017-03-24      95
# 2017-03-25      79
# 2017-03-26      77
# 2017-03-27       5
# 2017-03-28      78
# 2017-03-29      41
# 2017-03-30      10
# 2017-03-31      10
# 2017-04-01      88
# 2017-04-02      19
# ...            ...
# 2017-08-22      86
# 2017-08-23      36
# 2017-08-24      59
# 2017-08-25      76
# 2017-08-26       7
# 2017-08-27       1
# 2017-08-28      40
# 2017-08-29      16
# 2017-08-30      49
# 2017-08-31      51
# 2017-09-01      33
# 2017-09-02      16
# 2017-09-03      50
# 2017-09-04       8
# 2017-09-05      40
# ...

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np

date_today = datetime.now().date()
ndays = 200
df = pd.DataFrame({'date': [date_today - timedelta(days=x) for x in range(ndays)], 
                   'number': pd.Series(np.random.randn(ndays))})
df=df.set_index('date')
df
# Out:
#               number
# date
# 2018-03-01  0.452784
# 2018-02-28  0.987335
# 2018-02-27  0.389116
# 2018-02-26 -0.983110
# 2018-02-25  1.281655
# 2018-02-24  1.587986
# 2018-02-23 -0.177154
# 2018-02-22  0.115123
# 2018-02-21  1.244190
# 2018-02-20  0.969763
# 2018-02-19 -0.328278
# 2018-02-18  0.548095
# 2018-02-17  0.757209
# 2018-02-16 -0.672454
# 2018-02-15  1.239705
# 2018-02-14 -0.513663
# 2018-02-13  0.303160
# 2018-02-12  0.376452
# 2018-02-11 -0.214082
# 2018-02-10  0.390213
# 2018-02-09  0.656651
# 2018-02-08  1.313468
# 2018-02-07 -1.052178
# 2018-02-06 -1.182220
# 2018-02-05 -0.487118
# 2018-02-04 -0.893224
# 2018-02-03  2.173265
# 2018-02-02  0.380394
# 2018-02-01 -0.340507
# 2018-01-31  0.871157
# ...              ...
# 2017-09-12 -0.277273
# 2017-09-11  0.358662
# 2017-09-10  1.441941
# 2017-09-09  0.062217
# 2017-09-08  0.224378
# 2017-09-07  0.485359
# 2017-09-06  0.023980
# 2017-09-05 -0.555674
# 2017-09-04 -2.238655
# 2017-09-03 -1.015384
# 2017-09-02 -1.070541
# ...

# %%
df.truncate(before=(datetime(2017,9,12).date())).number[0]
# Out:
# 72

# %%
df.iloc[df.index.get_loc(datetime(2017,9,12),method='nearest')]
# Out:
# number   -0.277273
# Name: 2017-09-12, dtype: float64
